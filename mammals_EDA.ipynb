# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Open dataset
mammals_df = pd.read_csv('Resources/mammals.csv')
mammals_df.head()
# Out:
#                   species   body_wt  brain_wt  non_dreaming  dreaming  \
# 0         Africanelephant  6654.000    5712.0           NaN       NaN
# 1  Africangiantpouchedrat     1.000       6.6           6.3       2.0
# 2               ArcticFox     3.385      44.5           NaN       NaN
# 3    Arcticgroundsquirrel     0.920       5.7           NaN       NaN
# 4           Asianelephant  2547.000    4603.0           2.1       1.8
#
#    total_sleep  life_span  gestation  predation  exposure  danger
# 0          3.3       38.6      645.0          3         5       3
# 1          8.3        4.5       42.0          3         1       3
# 2         12.5       14.0       60.0          1         1       1
# 3         16.5        NaN       25.0          5         2       3
# 4          3.9       69.0      624.0          3         5       4

# %%
# columns
mammals_df.columns.to_list()
# Out:
# ['species',
#  'body_wt',
#  'brain_wt',
#  'non_dreaming',
#  'dreaming',
#  'total_sleep',
#  'life_span',
#  'gestation',
#  'predation',
#  'exposure',
#  'danger']

# %%
mammals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   species       62 non-null     object
#  1   body_wt       62 non-null     float64
#  2   brain_wt      62 non-null     float64
#  3   non_dreaming  48 non-null     float64
#  4   dreaming      50 non-null     float64
#  5   total_sleep   58 non-null     float64
#  6   life_span     58 non-null     float64
#  7   gestation     58 non-null     float64
#  8   predation     62 non-null     int64
#  9   exposure      62 non-null     int64
#  10  danger        62 non-null     int64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 5.5+ KB

# %%
# find out the unique value to make categorical variable
print('Species')
print(*list(mammals_df.species.unique()))
print('Body Weight')
print(*list(mammals_df.body_wt.unique()))
print('Brain Weight')
print(*list(mammals_df.brain_wt.unique()))
print('Dreaming')
print(*list(mammals_df.dreaming.unique()))
print('Non-dreaming')
print(*list(mammals_df.non_dreaming.unique()))
print('Total Sleep')
print(*list(mammals_df.total_sleep.unique()))
print('Life Span')
print(*list(mammals_df.life_span.unique()))
print('Gestation')
print(*list(mammals_df.gestation.unique()))
print('Predation')
print(*list(mammals_df.predation.unique()))
print('Exposure')
print(*list(mammals_df.exposure.unique()))
print('Danger')
print(*list(mammals_df.danger.unique()))
# Out:
# Species
# Africanelephant Africangiantpouchedrat ArcticFox Arcticgroundsquirrel Asianelephant Baboon Bigbrownbat Braziliantapir Cat Chimpanzee Chinchilla Cow Deserthedgehog Donkey EasternAmericanmole Echidna Europeanhedgehog Galago Genet Giantarmadillo Giraffe Goat Goldenhamster Gorilla Grayseal Graywolf Groundsquirrel Guineapig Horse Jaguar Kangaroo Lessershort-tailedshrew Littlebrownbat Man Molerat Mountainbeaver Mouse Muskshrew NAmericanopossum Nine-bandedarmadillo Okapi Owlmonkey Patasmonkey Phanlanger Pig Rabbit Raccoon Rat Redfox Rhesusmonkey Rockhyrax(Heterob) Rockhyrax(Procaviahab) Roedeer Sheep Slowloris Starnosedmole Tenrec Treehyrax Treeshrew Vervet Wateropossum Yellow-belliedmarmot
# Body Weight
# ...

# %%
# Looking at totals 
mammals_df.describe()
# Out:
#            body_wt     brain_wt  non_dreaming   dreaming  total_sleep  \
# count    62.000000    62.000000     48.000000  50.000000    58.000000
# mean    198.789984   283.134194      8.672917   1.972000    10.532759
# std     899.158011   930.278942      3.666452   1.442651     4.606760
# min       0.005000     0.140000      2.100000   0.000000     2.600000
# 25%       0.600000     4.250000      6.250000   0.900000     8.050000
# 50%       3.342500    17.250000      8.350000   1.800000    10.450000
# 75%      48.202500   166.000000     11.000000   2.550000    13.200000
# max    6654.000000  5712.000000     17.900000   6.600000    19.900000
#
#         life_span   gestation  predation   exposure     danger
# count   58.000000   58.000000  62.000000  62.000000  62.000000
# mean    19.877586  142.353448   2.870968   2.419355   2.612903
# std     18.206255  146.805039   1.476414   1.604792   1.441252
# min      2.000000   12.000000   1.000000   1.000000   1.000000
# ...

# %%
# Looking at NAN
mammals_df.isnull().sum()
# Out:
# species          0
# body_wt          0
# brain_wt         0
# non_dreaming    14
# dreaming        12
# total_sleep      4
# life_span        4
# gestation        4
# predation        0
# exposure         0
# danger           0
# dtype: int64

# %%
#Visual Analysis of dreaming 
sn.factorplot(x='dreaming', kind='count', data=mammals_df, height=8, aspect=15/8)

# %%
#Visual Analysis of non-dreaming 
sn.factorplot('non_dreaming', kind='count', data=mammals_df, height=8, aspect=15/8)

# %%
#heatmap 
corr=mammals_df.corr(method='spearman')
plt.figure(figsize=(15,15))
sn.heatmap(corr,vmax=.8,linewidths=0.01,square=True,annot=True,cmap='YlGnBu',linecolor='black')
# Out:
# <AxesSubplot:>

# %%
#dreaming Vs predation
b = sn.barplot(x=mammals_df.dreaming, y=mammals_df.predation)

#Increasing font size
sn.set(font_scale=3)
b.set_xlabel("Dreaming", fontsize = 30)
b.set_ylabel("Predation", fontsize = 30)
# Out:
# Text(0, 0.5, 'Predation')

# %%
#non-dreaming Vs predation
b = sn.barplot(x=mammals_df.non_dreaming, y=mammals_df.predation)

#Increasing font size
sn.set(font_scale=1.4)
b.set_xlabel("Non-Dreaming", fontsize = 30)
b.set_ylabel("Predation", fontsize = 30)
# Out:
# Text(0, 0.5, 'Predation')

# %%
#total sleep Vs predation
b = sn.barplot(x=mammals_df.total_sleep, y=mammals_df.predation)

#Increasing font size
sn.set(font_scale=1.4)
b.set_xlabel("Total Sleep", fontsize = 30)
b.set_ylabel("Predation", fontsize = 30)
# Out:
# Text(0, 0.5, 'Predation')

# %%
#total sleep Vs predation
b = sn.barplot(x=mammals_df.species, y=mammals_df.total_sleep)

#Increasing font size
sn.set(font_scale=1.4)
plt.xticks(rotation=45)
b.set_xlabel("Species", fontsize = 30)
b.set_ylabel("Total Sleep", fontsize = 30)
# Out:
# Text(0, 0.5, 'Total Sleep')
